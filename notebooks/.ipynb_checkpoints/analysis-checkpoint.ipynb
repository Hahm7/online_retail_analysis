# %% [markdown]
# # E-commerce Sales Analysis
#
# **Dataset:** Cleaned the UCI Online Retail II dataset to produce 1,021,271 transactions spanning 1 Dec 2009 – 9 Dec 2011.
#
# **Objective:** Analyze transactions to identify revenue drivers, high-value customer segments and changes in trading across the two years.
#
# **Author:** Hamdi Ahmed
# **Date:** 11/06/2026

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
import duckdb
import pandas as pd

cleaned = pd.read_csv('../data/processed/cleaned.csv')
registered = pd.read_csv('../data/processed/registered_only.csv')

from IPython.display import HTML, display


display(HTML("""
<script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/4.4.1/chart.umd.js"></script>
<script>window._chartjsLoaded = true;</script>
"""))


print(f"Loaded {len(cleaned):,} rows for cleaned data")
print(f"Loaded {len(registered):,} rows for cleaned data with registered customers only")
pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/4.4.1/chart.umd.js"></script>
# <script>window._chartjsLoaded = true;</script>
# Loaded 1,021,271 rows for cleaned data
# Loaded 794,182 rows for cleaned data with registered customers only

# %%
con = duckdb.connect()
con.register('cleaned', cleaned)
con.register('registered', registered)


print("Columns:", list(cleaned.columns))
# Out:
# Columns: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'CustomerID', 'Country', 'is_cancellation', 'is_guest', 'Revenue', 'Year', 'Month', 'DayOfWeek', 'Hour', 'IsWeekend', 'WeekStart', 'MonthStart']

# %% [markdown]
# ## 2. Is The Business Growing?

# %%
totals = con.execute("""
    SELECT
        SUM(Revenue) as total_revenue,
        COUNT(DISTINCT Invoice) AS total_orders,
        COUNT(DISTINCT CustomerID) AS total_customers
    FROM
        cleaned
    WHERE 
        is_cancellation = 0 AND Quantity > 0
""").fetchdf()

totals
# Out:
#    total_revenue  total_orders  total_customers
# 0  19,644,818.67         39529             5852

# %%
# Comparing revenue, orders and customer total over the two years
con.execute("""
    WITH sales AS (
        SELECT
            CAST(InvoiceDate AS DATE) AS invoice_date,
            Invoice,
            CustomerID,
            Revenue
        FROM 
            cleaned
        WHERE is_cancellation = 0
          AND Quantity > 0
    ),
    tagged AS (
        SELECT
            *,
            CASE
                WHEN invoice_date >= DATE '2009-12-01'
                 AND invoice_date <  DATE '2010-12-01' THEN 'Year 1: Dec09-Nov10'
                WHEN invoice_date >= DATE '2010-12-01'
                 AND invoice_date <  DATE '2011-12-01' THEN 'Year 2: Dec10-Nov11'
            END AS trading_year
        FROM sales
    ),
    yearly AS (
        SELECT
            trading_year,
            ROUND(SUM(Revenue), 0) AS revenue,
            COUNT(DISTINCT Invoice) AS orders,
            COUNT(DISTINCT CustomerID) AS customers,
            ROUND(SUM(Revenue) / COUNT(DISTINCT Invoice), 2) AS avg_order_value
        FROM 
            tagged
        WHERE 
            trading_year IS NOT NULL
        GROUP BY 
            trading_year
        ORDER BY 
            trading_year
    )
    SELECT
        trading_year,
        revenue,
        orders,
        avg_order_value,
        ROUND((revenue / LAG(revenue) OVER (ORDER BY trading_year) - 1) * 100, 1)
            AS revenue_pct_change,
        ROUND((orders / LAG(orders) OVER (ORDER BY trading_year) - 1) * 100, 1)
            AS orders_pct_change,
        ROUND((avg_order_value / LAG(avg_order_value) OVER (ORDER BY trading_year) - 1) * 100, 1)
            AS average_order_value_pct_change
    FROM 
        yearly
    ORDER BY 
        trading_year
""").fetchdf()
# Out:
#           trading_year      revenue  orders  avg_order_value  \
# 0  Year 1: Dec09-Nov10 9,397,599.00   19756           475.68
# 1  Year 2: Dec10-Nov11 9,632,728.00   18957           508.14
#
#    revenue_pct_change  orders_pct_change  average_order_value_pct_change
# 0                 NaN                NaN                             NaN
# 1                2.50              -4.00                            6.80

# %% [markdown]
# ### Insight:
#     - Revenue broadly flat across the two years, it grew by 2.5%.
#     - Orders decreased by 4% but the average order value rose by 6.8%. Fewer transactions but each is worth more

# %% [markdown]
# ## 2. Revenue Analysis

# %%
# Gross vs Net Revenue
con.execute("""
    WITH flagged AS (
        SELECT
            CAST(InvoiceDate AS DATE) AS invoice_date,
            CASE WHEN is_cancellation = 0 AND Quantity > 0
                 THEN Revenue ELSE 0 END AS gross_revenue,
            CASE WHEN is_cancellation = 1
                 THEN ABS(Revenue) ELSE 0 END AS returned_revenue
        FROM cleaned
    ),
    tagged AS (
        SELECT
            *,
            CASE
                WHEN invoice_date >= DATE '2009-12-01'
                 AND invoice_date <  DATE '2010-12-01' THEN 'Year 1: Dec09-Nov10'
                WHEN invoice_date >= DATE '2010-12-01'
                 AND invoice_date <  DATE '2011-12-01' THEN 'Year 2: Dec10-Nov11'
            END AS trading_year
        FROM flagged
    )
    SELECT
        trading_year,
        ROUND(SUM(gross_revenue), 0) AS gross_revenue,
        ROUND(SUM(returned_revenue), 0) AS returns,
        ROUND(SUM(gross_revenue) - SUM(returned_revenue), 0) AS net_revenue,
        ROUND(SUM(returned_revenue) / SUM(gross_revenue) * 100, 1) AS return_rate_pct
    FROM tagged
    WHERE trading_year IS NOT NULL
    GROUP BY ROLLUP 
        (trading_year)
    ORDER BY 
        trading_year
""").fetchdf()
# Out:
#           trading_year  gross_revenue    returns   net_revenue  \
# 0  Year 1: Dec09-Nov10   9,397,599.00 240,547.00  9,157,052.00
# 1  Year 2: Dec10-Nov11   9,632,728.00 301,810.00  9,330,919.00
# 2                  NaN  19,030,328.00 542,357.00 18,487,971.00
#
#    return_rate_pct
# 0             2.60
# 1             3.10
# 2             2.80

# %%
# Cancellation Rate over time

con.execute("""
    WITH monthly_orders AS (
        SELECT
            DATE_TRUNC('month', CAST(InvoiceDate AS DATE)) AS month,
            Invoice,
            is_cancellation,
            Quantity
        FROM cleaned
        WHERE CAST(InvoiceDate AS DATE) < DATE '2011-12-01'
    )
    SELECT
        month,
        COUNT(DISTINCT CASE WHEN is_cancellation = 0 AND Quantity > 0
                            THEN Invoice END) AS valid_orders,
        COUNT(DISTINCT CASE WHEN is_cancellation = 1
                            THEN Invoice END) AS cancelled_orders,
        ROUND(
            COUNT(DISTINCT CASE WHEN is_cancellation = 1 THEN Invoice END) * 100.0
            / COUNT(DISTINCT CASE WHEN is_cancellation = 0 AND Quantity > 0 THEN Invoice END)
        , 1) AS cancellation_rate_pct
    FROM monthly_orders
    GROUP BY month
    ORDER BY month
""").fetchdf()
# Out:
#         month  valid_orders  cancelled_orders  cancellation_rate_pct
# 0  2009-12-01          1671               379                  22.70
# 1  2010-01-01          1053               241                  22.90
# 2  2010-02-01          1189               219                  18.40
# 3  2010-03-01          1647               351                  21.30
# 4  2010-04-01          1436               263                  18.30
# 5  2010-05-01          1484               387                  26.10
# 6  2010-06-01          1615               318                  19.70
# 7  2010-07-01          1507               314                  20.80
# 8  2010-08-01          1402               242                  17.30
# 9  2010-09-01          1789               319                  17.80
# 10 2010-10-01          2244               410                  18.30
# 11 2010-11-01          2719               544                  20.00
# 12 2010-12-01          1550               301                  19.40
# 13 2011-01-01          1081               247                  22.80
# 14 2011-02-01          1093               191                  17.50
# 15 2011-03-01          1440               281                  19.50
# 16 2011-04-01          1235               220                  17.80
# 17 2011-05-01          1668               267                  16.00
# 18 2011-06-01          1525               299                  19.60
# 19 2011-07-01          1452               236                  16.30
# 20 2011-08-01          1339               240                  17.90
# 21 2011-09-01          1818               299                  16.40
# 22 2011-10-01          2005               308                  15.40
# 23 2011-11-01          2751               396                  14.40

# %%
from IPython.display import Image
Image('../docs/img/monthly_cancellation.png', width=1000, height=600)

# %%
# Monthly total revenue, orders and customers

con.execute("""
    WITH valid_sales AS (
        SELECT *
        FROM cleaned
        WHERE is_cancellation = 0
          AND Quantity > 0
          AND CAST(InvoiceDate AS DATE) < DATE '2011-12-01'
    )
    SELECT
        DATE_TRUNC('month', CAST(InvoiceDate AS DATE)) AS month_year,
        ROUND(SUM(Revenue), 0) AS gross_revenue,
        COUNT(DISTINCT Invoice) AS orders,
        COUNT(DISTINCT CustomerID) AS customers
    FROM valid_sales
    GROUP BY 
        month_year
    ORDER BY 
        gross_revenue DESC
""").fetchdf()
# Out:
#    month_year  gross_revenue  orders  customers
# 0  2011-11-01   1,452,116.00    2751       1660
# 1  2010-11-01   1,429,701.00    2719       1606
# 2  2011-10-01   1,103,314.00    2005       1361
# 3  2010-10-01   1,094,436.00    2244       1492
# 4  2011-09-01   1,028,320.00    1818       1259
# 5  2010-09-01     869,243.00    1789       1136
# 6  2009-12-01     798,015.00    1671        952
# 7  2010-12-01     775,638.00    1550        884
# 8  2010-03-01     761,706.00    1647       1051
# 9  2011-05-01     739,953.00    1668       1054
# 10 2011-06-01     737,559.00    1525        990
# 11 2011-08-01     724,217.00    1339        933
# 12 2010-06-01     697,314.00    1615       1035
# 13 2011-03-01     689,834.00    1440        973
# 14 2011-07-01     688,219.00    1452        946
# 15 2010-08-01     674,038.00    1402        910
# 16 2011-01-01     670,380.00    1081        739
# 17 2010-04-01     646,363.00    1436        939
# 18 2010-05-01     643,492.00    1484        965
# 19 2010-07-01     632,994.00    1507        924
# 20 2010-01-01     612,387.00    1053        702
# 21 2010-02-01     537,910.00    1189        771
# 22 2011-04-01     515,378.00    1235        853
# 23 2011-02-01     507,800.00    1093        757

# %%
Image('../docs/img/monthly_rev_orders_cust.png', width=1000, height=600)

# %%
con.execute("""
    WITH valid_sales AS (
        SELECT *
        FROM cleaned
        WHERE is_cancellation = 0
          AND Quantity > 0
          AND CAST(InvoiceDate AS DATE) < DATE '2011-12-01'
    ),
    monthly_totals AS (
        SELECT
            DATE_TRUNC('month', CAST(InvoiceDate AS DATE)) AS month_year,
            ROUND(SUM(Revenue), 0) AS gross_revenue,
            COUNT(DISTINCT Invoice) AS orders,
            COUNT(DISTINCT CustomerID) AS customers
        FROM valid_sales
        GROUP BY 
            month_year
    )
    SELECT
        strftime(month_year, '%B') AS month,
        ROUND(AVG(gross_revenue), 1) AS average_gross_revenue,
        ROUND(AVG(orders), 1) AS average_orders,
        ROUND(AVG(customers), 1) AS average_customers
    FROM
        monthly_totals
    GROUP BY
        month
    ORDER BY
        average_gross_revenue DESC 
""").fetchdf()
# Out:
#         month  average_gross_revenue  average_orders  average_customers
# 0    November           1,440,908.50        2,735.00           1,633.00
# 1     October           1,098,875.00        2,124.50           1,426.50
# 2   September             948,781.50        1,803.50           1,197.50
# 3    December             786,826.50        1,610.50             918.00
# 4       March             725,770.00        1,543.50           1,012.00
# 5        June             717,436.50        1,570.00           1,012.50
# 6      August             699,127.50        1,370.50             921.50
# 7         May             691,722.50        1,576.00           1,009.50
# 8        July             660,606.50        1,479.50             935.00
# 9     January             641,383.50        1,067.00             720.50
# 10      April             580,870.50        1,335.50             896.00
# 11   February             522,855.00        1,141.00             764.00

# %%
Image('../docs/img/average_monthly_revenue_chart.png')

# %% [markdown]
# ### Insight:
#     - Headline revenue is £19.6m gross, net of returned orders it is £18.5m giving a return rate of 2.9%
#     - Cancellations are falling across the two years
#     - Using gross figure for monthly revenue analysis as returns might not happen in the same month of sale
#     - November is the strongest month in both years

# %% [markdown]
# ## 3. Customer Segmentation

# %%
# Recency = Number of days since last purchase

# Frequency = Number of purchases made

# Monetary = Total amount spent


rfm_raw = con.execute("""
    SELECT
        CustomerID,
        DATE_DIFF('day',
            MAX(CAST(InvoiceDate AS DATE)),
            (SELECT MAX(CAST(InvoiceDate AS DATE)) + INTERVAL '1 day' FROM registered)
        ) AS Recency,
        COUNT(DISTINCT Invoice) AS Frequency,
        SUM(Revenue) AS Monetary
    FROM 
        registered
    WHERE 
        is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
""").fetchdf()

rfm_raw
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0      15,005.00       16         56 13,752.58
# 1      17,214.00       61          6  1,059.12
# 2      14,841.00       54         14  7,163.00
# 3      16,985.00       18         23 10,923.16
# 4      17,062.00      314          6    884.71
# ...          ...      ...        ...       ...
# 5847   13,829.00      422          1    102.00
# 5848   15,893.00      482          1    305.28
# 5849   13,688.00      636          1    375.50
# 5850   13,128.00      632          1    263.50
# 5851   13,298.00        2          1    360.00
#
# [5852 rows x 4 columns]

# %%
rfm_columns = ['CustomerID', 'Recency', 'Frequency', 'Monetary']

query_parts = []

for column in rfm_columns:
    piece = f"""
    SELECT 
        '{column}' as column_name,
        COUNT(*) as total,
        MIN({column}) as min,
        QUANTILE_CONT({column},0.25) as qntile_25,
        QUANTILE_CONT({column},0.5) as median,
        QUANTILE_CONT({column},0.75) as qntile_75,
        MAX({column}) as max,
        ROUND(AVG({column}),2) as mean  
    FROM 
        rfm_raw
    """
    query_parts.append(piece)
rfm_distribution_query = " UNION ALL ".join(query_parts)

# %%
rfm_distribution_df = con.execute(rfm_distribution_query).fetchdf()
rfm_distribution_df
# Out:
#   column_name  total       min  qntile_25    median  qntile_75        max  \
# 0  CustomerID   5852 12,346.00  13,837.75 15,320.50  16,802.25  18,287.00
# 1     Recency   5852      1.00      26.00     96.00     380.00     739.00
# 2   Frequency   5852      1.00       1.00      3.00       7.00     373.00
# 3    Monetary   5852      2.95     339.58    856.02   2,241.03 580,987.04
#
#        mean
# 0 15,319.71
# 1    200.73
# 2      6.26
# 3  2,916.87

# %%
rfm_segments = con.execute("""
    WITH rfm_scored AS (
        SELECT *,
            NTILE(5) OVER (ORDER BY Recency  DESC) AS R_Score,
            NTILE(5) OVER (ORDER BY Frequency ASC) AS F_Score,
            NTILE(5) OVER (ORDER BY Monetary  ASC) AS M_Score
        FROM rfm_raw
    )
    SELECT *,
        CAST(R_Score AS VARCHAR) || 
        CAST(F_Score AS VARCHAR) || 
        CAST(M_Score AS VARCHAR) AS RFM_Score,
        CASE
            WHEN R_Score >= 4 AND F_Score >= 4 AND M_Score >= 4 THEN 'Champions'
            WHEN R_Score >= 3 AND F_Score >= 3 AND M_Score >= 3 THEN 'Loyal'
            WHEN R_Score >= 4 AND F_Score <= 2 THEN 'New Customers'
            WHEN R_Score >= 3 AND F_Score <= 2 THEN 'Promising'
            WHEN R_Score <= 2 AND F_Score >= 3 AND M_Score >= 3 THEN 'At Risk'
            WHEN R_Score <= 2 AND F_Score <= 2 THEN 'Lost'
            ELSE 'Needs Attention'
        END AS Segment
    FROM 
        rfm_scored
""").fetchdf()
rfm_segments
# Out:
#       CustomerID  Recency  Frequency   Monetary  R_Score  F_Score  M_Score  \
# 0      14,095.00      723          1       2.95        1        1        1
# 1      13,788.00      506          1       3.75        1        1        1
# 2      16,738.00      298          1       3.75        2        1        1
# 3      14,792.00       64          1       6.20        3        2        1
# 4      15,913.00      535          1       6.30        1        1        1
# ...          ...      ...        ...        ...      ...      ...      ...
# 5847   17,450.00        9         51 244,784.25        5        5        5
# 5848   14,911.00        2        373 272,252.79        5        5        5
# 5849   14,156.00       10        144 303,069.88        5        5        5
# 5850   14,646.00        2        145 526,751.52        5        5        5
# 5851   18,102.00        1        145 580,987.04        5        5        5
#
#      RFM_Score    Segment
# 0          111       Lost
# 1          111       Lost
# 2          211       Lost
# 3          321  Promising
# 4          111       Lost
# ...        ...        ...
# 5847       555  Champions
# 5848       555  Champions
# 5849       555  Champions
# 5850       555  Champions
# 5851       555  Champions
#
# [5852 rows x 9 columns]

# %%
con.execute("""
    SELECT
        Segment,
        COUNT(*) AS Customers,
        ROUND(SUM(Monetary), 2) AS Total_Revenue,
        ROUND(AVG(Monetary), 2) AS Avg_Revenue
    FROM 
        rfm_segments
    GROUP BY 
        Segment
    ORDER BY 
        Total_Revenue DESC
""").fetchdf()
# Out:
#            Segment  Customers  Total_Revenue  Avg_Revenue
# 0        Champions       1320  11,684,125.72     8,851.61
# 1            Loyal       1158   2,680,215.23     2,314.52
# 2          At Risk        583   1,471,705.89     2,524.37
# 3             Lost       1631     691,217.71       423.80
# 4        Promising        393     210,745.40       536.25
# 5  Needs Attention        449     183,647.89       409.02
# 6    New Customers        318     147,881.93       465.04

# %%
from IPython.display import IFrame

# Load Chart.js from local file
with open('../chart.umd.js', 'r') as f:
    chartjs = f.read()

# Run query and save result
rfm_summary = con.execute("""
    SELECT
        Segment,
        COUNT(*) AS Customers,
        ROUND(SUM(Monetary), 2) AS Total_Revenue,
        ROUND(AVG(Monetary), 2) AS Avg_Revenue
    FROM 
        rfm_segments
    GROUP BY 
        Segment
    ORDER BY 
        Total_Revenue DESC
""").fetchdf()

# Extract values from DataFrame
segments   = rfm_summary['Segment'].tolist()
customers  = rfm_summary['Customers'].tolist()
revenue    = rfm_summary['Total_Revenue'].tolist()
total_rev  = sum(revenue)
total_cust = sum(customers)

# Dynamic insight numbers
top_seg      = segments[0]
top_cust_pct = round(customers[0] / total_cust * 100)
top_rev_pct  = round(revenue[0] / total_rev * 100)

# Assign colours by segment name so order does not matter
colour_map = {
    'Champions':'#534AB7',
    'Loyal': '#0F6E56',
    'At Risk': '#D85A30',
    'Lost': '#888780',
    'Needs Attention': '#CC79A7',
    'New Customers': '#BA7517',
    'Promising': '#E69F00'  
}
seg_colours = [colour_map.get(s, '#888780') for s in segments]
bar_colours = ['#534AB7' if i == 0 else '#C8C5BB' for i in range(len(segments))]

# Build HTML
html_content = f"""<!DOCTYPE html>
<html>
<head>
<meta charset="UTF-8">
<link href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500&display=swap" rel="stylesheet">
<style>
body{{margin:0;padding:0}}
.rfm-wrap{{font-family:'Inter',sans-serif;padding:1.5rem 2rem;background:#fff;color:#18160F}}
.rfm-title{{font-size:22px;font-weight:500;color:#18160F;margin:0 0 4px;line-height:1.4}}
.rfm-sub{{font-size:15px;color:#6A6158;margin:0 0 20px}}
.rfm-grid{{display:grid;grid-template-columns:1fr 1fr;gap:40px}}
.rfm-clabel{{font-size:15px;color:#6A6158;margin:0 0 10px}}
.rfm-legend{{display:flex;gap:8px;flex-wrap:wrap;margin-top:12px}}
.rfm-legend span{{font-size:16px;color:#6A6158;display:flex;align-items:center;gap:4px}}
.rfm-legend i{{width:9px;height:9px;border-radius:2px;display:inline-block;flex-shrink:0}}
.rfm-source{{font-size:13px;color:#ABA49B;margin:16px 0 0}}
</style>
</head>
<body>
<div class="rfm-wrap">
  <p class="rfm-title">
    <span style="color:#534AB7;">{top_seg}</span> make up {top_cust_pct}% of customers
    but generate {top_rev_pct}% of total revenue
  </p>

  <br>

  <div class="rfm-grid">
    <div>
      <p class="rfm-clabel">Share of customers by segment</p>
      <div style="position:relative;width:100%;height:280px;">
        <canvas id="custChart"></canvas>
      </div>
      <div class="rfm-legend">
        {"".join(f'<span><i style="background:{colour_map.get(s, "#888780")};"></i>{s}</span>' for s in segments)}
      </div>
    </div>

    <div>
      <p class="rfm-clabel">Total revenue by segment (&pound;)</p>
      <div style="position:relative;width:100%;height:280px;">
        <canvas id="revChart"></canvas>
      </div>
    </div>
  </div>

  <p class="rfm-source">Source: UCI Machine Learning Repository &mdash; Online Retail II dataset</p>
</div>

<script>{chartjs}</script>
<script>
const segments = {segments};
const customers = {customers};
const revenue = {revenue};
const segColours = {seg_colours};
const barColours = {bar_colours};
const total = customers.reduce((a,b) => a+b, 0);
const fontFamily = "'Inter', sans-serif";

const pieLabelPlugin = {{
  id: 'pieDatalabels',
  afterDatasetsDraw(chart) {{
    const {{ctx, data}} = chart;
    const meta = chart.getDatasetMeta(0);
    meta.data.forEach((arc, i) => {{
      const pct = data.datasets[0].data[i] / total * 100;
      if (pct < 6) return;
      const angle = (arc.startAngle + arc.endAngle) / 2;
      const r = (arc.innerRadius + arc.outerRadius) / 2;
      const x = arc.x + Math.cos(angle) * r;
      const y = arc.y + Math.sin(angle) * r;
      ctx.save();
      ctx.font = '500 13px ' + fontFamily;
      ctx.fillStyle = '#ffffff';
      ctx.textAlign = 'center';
      ctx.textBaseline = 'middle';
      ctx.fillText(Math.round(pct) + '%', x, y);
      ctx.restore();
    }});
  }}
}};

const barLabelPlugin = {{
  id: 'barDatalabel',
  afterDatasetsDraw(chart) {{
    const {{ctx}} = chart;
    const meta = chart.getDatasetMeta(0);
    meta.data.forEach((bar, i) => {{
      const val = revenue[i];
      const label = val >= 1000000
        ? '\u00A3' + (val/1000000).toFixed(1) + 'M'
        : '\u00A3' + (val/1000).toFixed(0) + 'K';
      ctx.save();
      ctx.font = '500 16px ' + fontFamily;
      ctx.fillStyle = i === 0 ? '#534AB7' : '#888780';
      ctx.textAlign = 'center';
      ctx.textBaseline = 'bottom';
      ctx.fillText(label, bar.x, bar.y - 4);
      ctx.restore();
    }});
  }}
}};

new Chart(document.getElementById('custChart'), {{
  type: 'pie',
  data: {{
    labels: segments,
    datasets: [{{
      data: customers,
      backgroundColor: segColours,
      borderWidth: 2,
      borderColor: '#ffffff'
    }}]
  }},
  options: {{
    responsive: true,
    maintainAspectRatio: false,
    plugins: {{
      legend: {{ display: false }},
      tooltip: {{
        callbacks: {{
          label: ctx => {{
            const pct = (ctx.parsed / total * 100).toFixed(1);
            return ' ' + ctx.label + ': ' + pct + '% (' + ctx.parsed.toLocaleString() + ' customers)';
          }}
        }}
      }}
    }}
  }},
  plugins: [pieLabelPlugin]
}});

new Chart(document.getElementById('revChart'), {{
  type: 'bar',
  data: {{
    labels: segments,
    datasets: [{{
      data: revenue,
      backgroundColor: barColours,
      borderRadius: 3,
      borderSkipped: false
    }}]
  }},
  options: {{
    responsive: true,
    maintainAspectRatio: false,
    layout: {{ padding: {{ top: 28 }} }},
    plugins: {{
      legend: {{ display: false }},
      tooltip: {{
        callbacks: {{
          label: ctx => ' \u00A3' + (ctx.parsed.y / 1000000).toFixed(2) + 'M'
        }}
      }}
    }},
    scales: {{
      x: {{
        grid: {{ display: false }},
        border: {{ display: false }},
        ticks: {{
        font: {{ size: 16, family: fontFamily }},
        color: (ctx) => ctx.index === 0 ? '#534AB7' : '#888780',
        maxRotation: 15,
        autoSkip: false
        }}  
      }},
      y: {{
        display: false
      }}
    }}
  }},
  plugins: [barLabelPlugin]
}});
</script>
</body>
</html>"""

# Save and display in iframe
with open('../docs/img/rfm_segments.html', 'w') as f:
    f.write(html_content)

IFrame('../docs/img/rfm_segments.html', width=1100, height=560)
# Out:
#         <iframe
#             width="1100"
#             height="560"
#             src="../docs/img/rfm_segments.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
Image('../docs/img/rfm_segments.png')

# %%
# How concentrated is the champions segment?
con.execute("""
    WITH champions AS (
        SELECT
            CustomerID,
            Monetary,
            ROW_NUMBER() OVER (ORDER BY Monetary DESC) AS revenue_rank,
            SUM(Monetary) OVER () AS segment_revenue
        FROM rfm_segments
        WHERE Segment = 'Champions'
    )
    SELECT
        COUNT(*) AS champions,
        ROUND(MAX(segment_revenue), 0) AS champions_revenue,
        ROUND(AVG(Monetary), 2) AS mean_champion,
        ROUND(MEDIAN(Monetary), 0) AS median_champion,
        ROUND(SUM(CASE WHEN revenue_rank <= 5  THEN Monetary ELSE 0 END)
              / MAX(segment_revenue) * 100, 1) AS top_5_share_pct,
        ROUND(SUM(CASE WHEN revenue_rank <= 25 THEN Monetary ELSE 0 END)
              / MAX(segment_revenue) * 100, 1) AS top_25_share_pct
    FROM champions
""").fetchdf()
# Out:
#    champions  champions_revenue  mean_champion  median_champion  \
# 0       1320      11,684,126.00       8,851.61         3,797.00
#
#    top_5_share_pct  top_25_share_pct
# 0            16.50             33.80

# %% [markdown]
# - The champions segment is heavily skewed. Half of all champions generate less than £3814 but the average revenue is more than double that
# - Just 25 customers hold a third of the segment's total revenue

# %%
# Does concentration hold across the whole customer base and is it changing?
con.execute("""

    WITH customer_year AS (
        SELECT
            CASE
                WHEN CAST(InvoiceDate AS DATE) >= DATE '2009-12-01'
                 AND CAST(InvoiceDate AS DATE) <  DATE '2010-12-01' THEN 'Year 1: Dec09-Nov10'
                WHEN CAST(InvoiceDate AS DATE) >= DATE '2010-12-01'
                 AND CAST(InvoiceDate AS DATE) <  DATE '2011-12-01' THEN 'Year 2: Dec10-Nov11'
            END AS trading_year,
            CustomerID,
            SUM(Revenue) AS customer_revenue
        FROM 
            registered
        WHERE is_cancellation = 0 AND Quantity > 0
        GROUP BY 
            trading_year, 
            CustomerID
    ),
    ranked AS (
        SELECT
            *,
            ROW_NUMBER() OVER (PARTITION BY trading_year
                               ORDER BY customer_revenue DESC) AS revenue_rank,
            SUM(customer_revenue) OVER (PARTITION BY trading_year) AS year_revenue
        FROM 
            customer_year
        WHERE 
            trading_year IS NOT NULL
    )
    SELECT
        trading_year,
        COUNT(*) AS active_customers,
        ROUND(SUM(CASE WHEN revenue_rank <= 10 THEN customer_revenue ELSE 0 END)
              / MAX(year_revenue) * 100, 1) AS top_10_share_pct,
        ROUND(SUM(CASE WHEN revenue_rank <= 50 THEN customer_revenue ELSE 0 END)
              / MAX(year_revenue) * 100, 1) AS top_50_share_pct
    FROM ranked
    GROUP BY 
        trading_year
    ORDER BY 
        trading_year
    
""").fetchdf()
# Out:
#           trading_year  active_customers  top_10_share_pct  top_50_share_pct
# 0  Year 1: Dec09-Nov10              4239             16.50             30.10
# 1  Year 2: Dec10-Nov11              4293             16.70             32.30

# %% [markdown]
#  - Concentration exists but is not growing. The skew found within the champions segment is a feature of the tier and not a worsening trend

# %% [markdown]
# ## 4. Cohort Retention

# %%
con.execute("""
    WITH customer_month_base AS (
        SELECT
            CustomerID,
            DATE_TRUNC('month', CAST(InvoiceDate AS DATE)) AS InvoiceMonth
        FROM 
            registered
        WHERE 
            is_cancellation = 0 AND Quantity > 0
    ),
    first_purchase_month AS (
        SELECT 
            CustomerID,
            MIN(InvoiceMonth) AS CohortMonth
        FROM 
            customer_month_base
        GROUP BY 
            CustomerID
    ),
    cohorts AS (
        SELECT
            cb.CustomerID,
            cb.InvoiceMonth,
            fm.CohortMonth,
            DATE_DIFF('month', fm.CohortMonth, cb.InvoiceMonth) AS CohortIndex
        FROM 
            customer_month_base cb
        JOIN first_purchase_month fm ON cb.CustomerID = fm.CustomerID
    ),
    cohort_counts AS (
        SELECT
            CohortMonth,
            CohortIndex,
            COUNT(DISTINCT CustomerID) AS Customers
        FROM 
            cohorts
        GROUP BY 
            CohortMonth, CohortIndex
    ),
    cohort_size AS (
        SELECT
            CohortMonth,
            Customers AS CohortSize
        FROM 
            cohort_counts
        WHERE 
            CohortIndex = 0
    ),
    total_customers AS (
        SELECT SUM(CohortSize) AS TotalCohortSize
        FROM 
            cohort_size
    )
    SELECT
        cc.CohortIndex AS Month_Since_Acquisition,
        ROUND(100.0 * SUM(cc.Customers) / MAX(tc.TotalCohortSize), 1) AS Weighted_Retention_Pct
    FROM 
        cohort_counts cc
    CROSS JOIN total_customers tc
    GROUP BY 
        cc.CohortIndex
    ORDER BY 
        cc.CohortIndex
    LIMIT 13
""").fetchdf()
# Out:
#     Month_Since_Acquisition  Weighted_Retention_Pct
# 0                         0                  100.00
# 1                         1                   22.90
# 2                         2                   22.40
# 3                         3                   22.80
# 4                         4                   20.20
# 5                         5                   19.00
# 6                         6                   18.80
# 7                         7                   18.10
# 8                         8                   16.20
# 9                         9                   15.30
# 10                       10                   14.90
# 11                       11                   16.20
# 12                       12                   16.50

# %% [markdown]
# ### Insights:
# #### • Big drop happens after month 0 as 77% of new customers do not return after first purchase
# #### • Retention is nearly flat from month 1 to month 3

# %% [markdown]
# ## 5. Acquisition Quality

# %%
con.execute("""
    WITH sales AS (
        SELECT
            CustomerID,
            DATE_TRUNC('month', CAST(InvoiceDate AS DATE)) AS order_month
        FROM 
            registered
        WHERE is_cancellation = 0 AND Quantity > 0
    ),
    first_order AS (
        SELECT
            CustomerID,
            MIN(order_month) AS cohort_month
        FROM 
            sales
        GROUP BY 
            CustomerID
    ),
    monthly AS (
        SELECT
            s.order_month,
            COUNT(DISTINCT s.CustomerID) AS active_customers,
            COUNT(DISTINCT CASE WHEN f.cohort_month = s.order_month
                                THEN s.CustomerID END) AS new_customers
        FROM 
            sales s
        JOIN first_order f ON s.CustomerID = f.CustomerID
        GROUP BY 
            s.order_month
    )
    SELECT
        order_month,
        active_customers,
        new_customers,
        active_customers - new_customers AS returning_customers,
        ROUND(new_customers * 100.0 / active_customers, 1) AS pct_new
    FROM 
        monthly
    WHERE order_month >  DATE '2009-12-01' AND order_month <  DATE '2011-12-01'
    ORDER BY 
        order_month
""").fetchdf()
# Out:
#    order_month  active_customers  new_customers  returning_customers  pct_new
# 0   2010-01-01               702            368                  334    52.40
# 1   2010-02-01               771            375                  396    48.60
# 2   2010-03-01              1051            440                  611    41.90
# 3   2010-04-01               939            294                  645    31.30
# 4   2010-05-01               965            255                  710    26.40
# 5   2010-06-01              1035            267                  768    25.80
# 6   2010-07-01               924            185                  739    20.00
# 7   2010-08-01               910            163                  747    17.90
# 8   2010-09-01              1136            239                  897    21.00
# 9   2010-10-01              1492            375                 1117    25.10
# 10  2010-11-01              1606            326                 1280    20.30
# 11  2010-12-01               884             76                  808     8.60
# 12  2011-01-01               739             72                  667     9.70
# 13  2011-02-01               757            125                  632    16.50
# 14  2011-03-01               973            179                  794    18.40
# 15  2011-04-01               853            106                  747    12.40
# 16  2011-05-01              1054            111                  943    10.50
# 17  2011-06-01               990            108                  882    10.90
# 18  2011-07-01               946            101                  845    10.70
# 19  2011-08-01               933            107                  826    11.50
# 20  2011-09-01              1259            188                 1071    14.90
# 21  2011-10-01              1361            221                 1140    16.20
# 22  2011-11-01              1660            191                 1469    11.50

# %%
Image('../docs/img/new_customers_year_on_year.png', width=1000, height=600)

# %%
Image('../docs/img/new_vs_returning_customers.png', width=1000, height=600)

# %% [markdown]
# #### • Testing whether how much a customer spends on their first order predicts whether they come back.
#
# #### • Customers are split into four equal groups by first order value and their return rates compared.

# %%
con.execute("""
    WITH sales AS (
        SELECT
            CustomerID,
            Invoice,
            Revenue,
            InvoiceDate,
            FIRST_VALUE(Invoice) OVER (PARTITION BY CustomerID ORDER BY InvoiceDate, Invoice) AS first_invoice
        FROM 
            registered
        WHERE 
            is_cancellation = 0 AND Quantity > 0
    ),
    per_customer AS (
        SELECT
            CustomerID,
            COUNT(DISTINCT Invoice) AS orders,
            MIN(CAST(InvoiceDate AS DATE)) AS first_purchase_date,
            SUM(CASE WHEN Invoice = first_invoice THEN Revenue ELSE 0 END) AS first_order_value
        FROM 
            sales
        GROUP BY 
            CustomerID
    ),
    eligible AS (
        SELECT *
        FROM 
            per_customer
        WHERE 
            first_purchase_date < (SELECT MAX(CAST(InvoiceDate AS DATE)) FROM registered) - INTERVAL 3 MONTH
    ),
    bucketed AS (
        SELECT
            *,
            NTILE(4) OVER (ORDER BY first_order_value) AS quartile
        FROM eligible
    )
    SELECT
        quartile,
        ROUND(MIN(first_order_value), 0) AS min_first_order,
        ROUND(MAX(first_order_value), 0) AS max_first_order,
        COUNT(*) AS customers,
        ROUND(100.0 * SUM(CASE WHEN orders > 1 THEN 1 ELSE 0 END) / COUNT(*), 1) AS pct_returned
    FROM 
        bucketed
    GROUP BY 
        quartile
    ORDER BY 
        quartile
""").fetchdf()
# Out:
#    quartile  min_first_order  max_first_order  customers  pct_returned
# 0         1             1.00           167.00       1314         65.50
# 1         2           167.00           292.00       1313         75.70
# 2         3           292.00           443.00       1313         78.60
# 3         4           443.00        33,168.00       1313         84.90

# %% [markdown]
#     - Return rate rises at every step, from 65.5% for the lowest first-order spenders to 84.9% for the highest
#
#     - The sharpest jump is from the bottom quartile to the second (65.5% → 75.7%), very low first-order spenders are the group most likely to buy once and never return. Above roughly £167, return rates are high and similar

# %%
con.execute("""
    WITH sales AS (
        SELECT
            CustomerID,
            Invoice,
            Revenue,
            CAST(InvoiceDate AS DATE) AS invoice_date,
            FIRST_VALUE(Invoice) OVER (
                PARTITION BY CustomerID
                ORDER BY InvoiceDate, Invoice
            ) AS first_invoice
        FROM registered
        WHERE is_cancellation = 0
          AND Quantity > 0
    ),
    per_customer AS (
        SELECT
            CustomerID,
            MIN(invoice_date) AS first_purchase_date,
            SUM(CASE WHEN Invoice = first_invoice THEN Revenue ELSE 0 END) AS first_order_value
        FROM sales
        GROUP BY CustomerID
    ),
    returned_in_90_days AS (
        SELECT
            p.CustomerID,
            p.first_purchase_date,
            p.first_order_value,
            MAX(CASE WHEN s.invoice_date >  p.first_purchase_date
                      AND s.invoice_date <= p.first_purchase_date + INTERVAL 90 DAY
                     THEN 1 ELSE 0 END) AS returned_90d
        FROM per_customer p
        JOIN sales s ON s.CustomerID = p.CustomerID
        GROUP BY p.CustomerID, p.first_purchase_date, p.first_order_value
    )
    SELECT
        YEAR(first_purchase_date)           AS acquisition_year,
        COUNT(*)                            AS new_customers,
        ROUND(MEDIAN(first_order_value), 0) AS median_first_order,
        ROUND(AVG(returned_90d) * 100, 1)   AS pct_returned_within_90_days
    FROM returned_in_90_days
    WHERE first_purchase_date >= DATE '2010-01-01'
      AND first_purchase_date <  DATE '2011-09-10'
    GROUP BY acquisition_year
    ORDER BY acquisition_year
""").fetchdf()
# Out:
#    acquisition_year  new_customers  median_first_order  \
# 0              2010           3363              290.00
# 1              2011            941              284.00
#
#    pct_returned_within_90_days
# 0                        40.50
# 1                        42.40

# %% [markdown]
# - The 2011 intake is smaller (941 new customers vs 3,363) but not weaker as median first order similar (£284 vs £290) with a higher return rate

# %% [markdown]
# ## 6. Geographic Analysis

# %%
# Top 10 Countries By Revenue

top_country_revenue = con.execute("""
    WITH country_stats AS (
        SELECT 
            Country,
            Sum(Revenue) as Revenue,
            COUNT(DISTINCT CustomerID) as Customers,
            COUNT(DISTINCT Invoice) as Orders
        FROM
            cleaned
        WHERE 
            is_cancellation = 0 AND Quantity > 0
        GROUP BY
            Country
        ORDER BY
            Sum(Revenue) DESC
        LIMIT 10
    )
    SELECT 
        *,
        ROUND((Revenue / (SELECT SUM(Revenue) FROM cleaned))*100, 0) as "Market Share %",
        Orders/Customers as Order_Per_Customer
    FROM
        country_stats
""").fetchdf()

top_country_revenue
# Out:
#           Country       Revenue  Customers  Orders  Market Share %  \
# 0  United Kingdom 16,801,976.42       5334   36197           89.00
# 1            EIRE    623,414.16          3     581            3.00
# 2     Netherlands    549,773.41         22     216            3.00
# 3         Germany    383,289.00        107     753            2.00
# 4          France    311,090.29         93     598            2.00
# 5       Australia    167,800.01         15      89            1.00
# 6           Spain     97,766.75         38     144            1.00
# 7     Switzerland     94,024.59         22      85            0.00
# 8          Sweden     86,319.14         19      99            0.00
# 9         Denmark     67,422.69         12      42            0.00
#
#    Order_Per_Customer
# 0                6.79
# 1              193.67
# 2                9.82
# 3                7.04
# 4                6.43
# 5                5.93
# 6                3.79
# 7                3.86
# 8                5.21
# 9                3.50

# %%
Image('../docs/img/total_revenue_country.png', width=1000, height=600)

# %% [markdown]
# #### How many customers made orders for the top 5 international markets?

# %%
# Customer Orders and Revenue in EIRE
con.execute("""
    SELECT 
        CustomerID,
        COUNT(DISTINCT Invoice) as Orders,
        SUM(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        Country = 'EIRE' AND is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
    ORDER BY 
        Revenue DESC
""").fetchdf()
# Out:
#    CustomerID  Orders    Revenue
# 0   14,156.00     144 303,069.88
# 1   14,911.00     373 272,252.79
# 2         NaN      53  36,788.08
# 3   14,016.00      11  11,303.41

# %%
# Customer Orders and Revenue in Germany
con.execute("""
    SELECT 
        CustomerID,
        COUNT(DISTINCT Invoice) as Orders,
        SUM(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        Country = 'Germany' AND is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
    ORDER BY 
        Revenue DESC
""").fetchdf()
# Out:
#      CustomerID  Orders   Revenue
# 0     12,471.00      71 35,099.90
# 1     12,709.00      32 29,487.18
# 2     12,621.00      35 22,097.20
# 3     12,477.00       9 20,276.37
# 4     12,472.00      19 14,971.29
# ..          ...     ...       ...
# 102   12,622.00       1    162.10
# 103   12,522.00       2    156.72
# 104   12,738.00       1    137.35
# 105   12,652.00       1     97.05
# 106   12,568.00       1     52.00
#
# [107 rows x 3 columns]

# %%
# Customer Orders and Revenue in France
con.execute("""
    SELECT 
        CustomerID,
        COUNT(DISTINCT Invoice) as Orders,
        SUM(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        Country = 'France' AND is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
    ORDER BY 
        Revenue DESC
""").fetchdf()
# Out:
#     CustomerID  Orders   Revenue
# 0    12,678.00      15 32,595.18
# 1    12,681.00      44 26,936.76
# 2    12,731.00      17 25,631.71
# 3    12,682.00      51 20,736.22
# 4    14,277.00       8 16,789.16
# ..         ...     ...       ...
# 89   12,736.00       1    144.00
# 90   12,692.00       1    110.95
# 91   12,659.00       1     73.68
# 92   12,506.00       1     73.50
# 93   12,686.00       1     71.14
#
# [94 rows x 3 columns]

# %%
# Customer Orders and Revenue in Netherlands
con.execute("""
    SELECT 
        CustomerID,
        COUNT(DISTINCT Invoice) as Orders,
        SUM(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        Country = 'Netherlands' AND is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
    ORDER BY 
        Revenue DESC
""").fetchdf()
# Out:
#     CustomerID  Orders    Revenue
# 0    14,646.00     145 526,751.52
# 1    12,759.00       8   4,618.74
# 2    12,806.00       2   2,558.96
# 3    12,802.00       5   2,186.42
# 4    12,813.00       3   1,621.80
# 5    12,775.00       7   1,551.12
# 6    12,778.00       9   1,541.68
# 7    12,765.00       6   1,299.58
# 8    12,805.00       4   1,230.95
# 9    12,803.00       1   1,017.81
# 10   12,787.00       4     799.18
# 11   12,761.00       1     712.95
# 12   12,786.00       1     668.50
# 13   12,791.00       5     656.83
# 14   12,790.00       2     546.85
# 15   12,788.00       4     384.90
# 16   12,796.00       1     351.00
# 17   12,804.00       2     325.37
# 18   12,780.00       1     322.40
# 19   12,760.00       1     317.80
# 20   12,789.00       3     225.35
# 21   12,774.00       1      83.70

# %%
# Customer Orders and Revenue in Australia
con.execute("""
    SELECT 
        CustomerID,
        COUNT(DISTINCT Invoice) as Orders,
        SUM(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        Country = 'Australia' AND is_cancellation = 0 AND Quantity > 0
    GROUP BY 
        CustomerID
    ORDER BY 
        Revenue DESC
""").fetchdf()
# Out:
#     CustomerID  Orders    Revenue
# 0    12,415.00      24 144,033.37
# 1    12,431.00      21   7,699.79
# 2    12,388.00       8   3,901.11
# 3    12,424.00       4   3,340.03
# 4    12,393.00       6   2,399.45
# 5    12,422.00       6   1,749.65
# 6    12,389.00       3   1,433.33
# 7    12,434.00       3   1,103.43
# 8    16,321.00       7     604.55
# 9    12,386.00       2     401.90
# 10   12,411.00       1     346.90
# 11   12,392.00       1     234.75
# 12   12,400.00       1     205.25
# 13   12,416.00       1     202.56
# 14   12,387.00       1     143.94

# %%
# Country Cancellation Rates

country_cancellation = con.execute("""
    SELECT
        Country,
        COUNT(DISTINCT CustomerID) AS Customers,
        COUNT(DISTINCT CASE WHEN is_cancellation = 0 AND Quantity > 0 THEN Invoice END) AS Orders,
        COUNT(DISTINCT CASE WHEN is_cancellation = 1 THEN Invoice END) AS Cancelled_Orders,
        ROUND(
            COUNT(DISTINCT CASE WHEN is_cancellation = 1 THEN Invoice END)
            / COUNT(DISTINCT CASE WHEN is_cancellation = 0 AND Quantity > 0 THEN Invoice END) * 100
        , 2) AS "Cancellation_Rate_%"
    FROM
        cleaned
    WHERE
        Country IN ('Netherlands', 'EIRE', 'Germany', 'France', 'Australia')
    GROUP BY
        Country
    ORDER BY
        "Cancellation_Rate_%" DESC
""").fetchdf()

country_cancellation
# Out:
#        Country  Customers  Orders  Cancelled_Orders  Cancellation_Rate_%
# 0      Germany        107     753               282                37.45
# 1         EIRE          3     581               146                25.13
# 2    Australia         15      89                19                21.35
# 3       France         93     598               111                18.56
# 4  Netherlands         22     216                11                 5.09

# %%
Image('../docs/img/revenue_by_country.png', width=1000, height=600)

# %% [markdown]
# #### • EIRE generates the highest revenue by a non UK country but there are only 3 customers from that country suggesting wholesale/trade buyers placing enormous repeat orders.
# #### • Netherlands and Australia have more unique customers but vast majority of revenue driven by 1 customer

# %% [markdown]
# ## 7. Product Analysis

# %%
# Top 10 Products By Revenue

con.execute("""
    SELECT 
        StockCode,
        Description,
        Sum(Revenue) as Revenue,
        Sum(Quantity) as Quantity,
        COUNT(DISTINCT Invoice) as Orders
    FROM
        cleaned
    WHERE 
        is_cancellation = 0 AND Quantity > 0
    GROUP BY
        StockCode,
        Description
    ORDER BY
        Revenue DESC
    LIMIT 10
""").fetchdf()
# Out:
#   StockCode                          Description    Revenue  Quantity  Orders
# 0     22423             REGENCY CAKESTAND 3 TIER 330,590.32 26,478.00    3918
# 1    85123A   WHITE HANGING HEART T-LIGHT HOLDER 260,990.22 94,658.00    5455
# 2     23843          PAPER CRAFT , LITTLE BIRDIE 168,469.60 80,995.00       1
# 3     47566                        PARTY BUNTING 148,318.28 28,200.00    2674
# 4    85099B              JUMBO BAG RED RETROSPOT 148,073.47 77,699.00    3269
# 5     84879        ASSORTED COLOUR BIRD ORNAMENT 129,324.49 80,082.00    2807
# 6     22086       PAPER CHAIN KIT 50'S CHRISTMAS 117,760.29 35,084.00    2018
# 7     23166       MEDIUM CERAMIC TOP STORAGE JAR  81,700.92 78,033.00     247
# 8     79321                        CHILLI LIGHTS  80,540.88 15,841.00    1135
# 9     84347  ROTATING SILVER ANGELS T-LIGHT HLDR  71,300.40 31,409.00     756

# %%
Image('../docs/img/total_revenue_product.png', width=1000, height=600)

# %%
# Top 10 Cancelled Products By Quantity Returned
con.execute("""
    WITH product_stats AS (
        SELECT
            StockCode,
            Description,
            SUM(CASE WHEN is_cancellation = 1 THEN ABS(Quantity) ELSE 0 END) AS units_returned,
            SUM(CASE WHEN is_cancellation = 0 AND Quantity > 0 THEN Quantity ELSE 0 END) AS units_sold,
            COUNT(DISTINCT CASE WHEN is_cancellation = 0 AND Quantity > 0 THEN Invoice END) AS orders_placed
        FROM 
            cleaned
        GROUP BY 
            StockCode,
            Description
    )
    SELECT
        Description,
        units_returned,
        units_sold,
        orders_placed
    FROM 
        product_stats
    ORDER BY 
        units_returned DESC
    LIMIT 10
""").fetchdf()
# Out:
#                            Description  units_returned  units_sold  \
# 0          PAPER CRAFT , LITTLE BIRDIE       80,995.00   80,995.00
# 1       MEDIUM CERAMIC TOP STORAGE JAR       74,494.00   78,033.00
# 2  ROTATING SILVER ANGELS T-LIGHT HLDR        9,381.00   31,409.00
# 3         SET/6 FRUIT SALAD PAPER CUPS        7,140.00   16,615.00
# 4      SET/6 FRUIT SALAD  PAPER PLATES        7,008.00   15,919.00
# 5              POP ART PEN CASE & PENS        5,184.00   10,612.00
# 6   BLACK SILVER FLOWER T-LIGHT HOLDER        5,040.00   11,520.00
# 7        MULTICOLOUR SPRING FLOWER MUG        4,996.00   13,665.00
# 8              TEATIME PEN CASE & PENS        4,632.00   10,056.00
# 9         WHITE BIRD GARDEN DESIGN MUG        4,320.00    8,824.00
#
#    orders_placed
# 0              1
# 1            247
# 2            756
# 3            136
# 4            143
# 5             31
# 6             23
# 7            204
# 8             59
# 9             35

# %%
Image('../docs/img/products_returned.png')

# %% [markdown]
# ## 8. Time Patterns

# %%
# Revenue By Day of Week
revenue_day = con.execute("""
    WITH day_of_week AS (
        SELECT
            *,
            CASE
                WHEN DayOfWeek = 0 Then 'Sunday'
                WHEN DayOfWeek = 1 Then 'Monday'
                WHEN DayOfWeek = 2 Then 'Tuesday'
                WHEN DayOfWeek = 3 Then 'Wednesday'
                WHEN DayOfWeek = 4 Then 'Thursday'
                WHEN DayOfWeek = 5 Then 'Friday'
                ELSE 'Saturday'
            END AS Days
        FROM
            cleaned
        WHERE 
            is_cancellation = 0 AND Quantity > 0
    )
    SELECT
        Days,
        Sum(Revenue) as Revenue
    FROM 
        day_of_week
    GROUP BY
        Days
    ORDER BY
        Revenue DESC
""").fetchdf()

revenue_day
# Out:
#         Days      Revenue
# 0   Thursday 4,010,238.02
# 1    Tuesday 3,880,183.26
# 2     Monday 3,416,751.16
# 3  Wednesday 3,375,311.19
# 4     Friday 3,167,357.88
# 5     Sunday 1,785,174.11
# 6   Saturday     9,803.05

# %%
Image('../docs/img/revenue_by_day.png')

# %%
# Revenue By Hour

revenue_hour = con.execute("""
    SELECT
        Hour,
        Sum(Revenue) as Revenue
    FROM 
        cleaned
    WHERE 
        is_cancellation = 0 AND Quantity > 0
    GROUP BY
        Hour
    ORDER BY
        Revenue DESC
""").fetchdf()

revenue_hour
# Out:
#     Hour      Revenue
# 0     12 2,785,147.51
# 1     10 2,508,752.73
# 2     13 2,479,959.54
# 3     11 2,423,379.77
# 4     15 2,228,673.31
# 5     14 2,217,166.40
# 6      9 1,704,623.23
# 7     16 1,457,666.26
# 8     17   814,966.46
# 9      8   521,995.20
# 10    18   263,096.94
# 11    19   125,469.61
# 12     7    75,029.57
# 13    20    38,887.89
# 14     6         4.25

# %%
Image('../docs/img/revenue_by_hour.png')

# %% [markdown]
# ## 9. Key Findings Summary

# %%
print('=' * 60)
print('📊 KEY FINDINGS SUMMARY')
print('=' * 60)

uk_revenue = top_country_revenue.loc[top_country_revenue['Country'] == 'United Kingdom', 'Revenue'].values[0]
uk_share = (uk_revenue/totals['total_revenue'][0])*100

peak_day = revenue_day['Days'].iloc[0]
peak_hour = revenue_hour['Hour'].iloc[0]


print(f"""
1. REVENUE OVERVIEW
   • Total Revenue: £{totals['total_revenue'][0]:,.2f}
   • Total Orders: {totals['total_orders'][0]:,}
   • Average Order Value: £{totals['total_revenue'][0]/totals['total_orders'][0]:.2f}
   
2. SEASONALITY
   • November generates the highest average monthly revenue.
   • Recommendation: Launch targeted November marketing campaigns to capitalise on peak buying intent.

3. CUSTOMER SEGMENTS
   • Total Customers: {totals['total_customers'][0]:,}
   • {top_seg} generate {top_rev_pct}% of total revenue
   • Recommendation: Create VIP loyalty program for {top_seg}

4. ACQUISITION QUALITY
   • Customers that spend the least on first order are most likely to buy once and never return
   • Recommendation: Email low spend customers within 2 weeks of first purchase to help encourage a second purchase and turn them into regulars

5. GEOGRAPHIC INSIGHTS
   • UK: {uk_share:.0f}% of revenue
   • Top international: EIRE, Germany, France, Netherlands and Australia. Bulk of revenue in EIRE, Netherlands and Australia is driven by 1 customer
   • Recommendation: Invest in EU marketing and fulfillment for France. Look further into Germany's high cancelation rate ({country_cancellation['Cancellation_Rate_%'][0]}%) before taking action

7. TIMING PATTERNS
   • Peak day: {peak_day}
   • Peak hour: {int(peak_hour)}:00
   • Recommendation: Schedule campaigns around peak times

""")
# Out:
# ============================================================
# 📊 KEY FINDINGS SUMMARY
# ============================================================
#
# 1. REVENUE OVERVIEW
#    • Total Revenue: £19,644,818.67
#    • Total Orders: 39,529
#    • Average Order Value: £496.97
#
# 2. SEASONALITY
#    • November generates the highest average monthly revenue.
#    • Recommendation: Launch targeted November marketing campaigns to capitalise on peak buying intent.
#
# 3. CUSTOMER SEGMENTS
#    • Total Customers: 5,852
#    • Champions generate 68% of total revenue
#    • Recommendation: Create VIP loyalty program for Champions
#
# 4. ACQUISITION QUALITY
#    • Customers that spend the least on first order are most likely to buy once and never return
#    • Recommendation: Email low spend customers within 2 weeks of first purchase to help encourage a second purchase and turn them into regulars
#
# 5. GEOGRAPHIC INSIGHTS
#    • UK: 86% of revenue
#    • Top international: EIRE, Germany, France, Netherlands and Australia. Bulk of revenue in EIRE, Netherlands and Australia is driven by 1 customer
#    • Recommendation: Invest in EU marketing and fulfillment for France. Look further into Germany's high cancelation rate (37.45%) before taking action
#
# 7. TIMING PATTERNS
#    • Peak day: Thursday
#    • Peak hour: 12:00
#    • Recommendation: Schedule campaigns around peak times

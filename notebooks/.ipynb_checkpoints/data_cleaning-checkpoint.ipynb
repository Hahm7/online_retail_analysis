# %% [markdown]
# # E-commerce Sales - Data Cleaning
#
# **Objective:** Clean and prepare the raw data for analysis.
#
# **Input:** Raw transaction data
# **Output:** Cleaned dataset ready for analysis
#
# **Author:** Hamdi Ahmed
# **Date:** 5/07/2026

# %% [markdown]
# # 1. Setup

# %%
import duckdb
import pandas as pd

df1 = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name='Year 2009-2010')
df2 = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name='Year 2010-2011')
raw = pd.concat([df1, df2], ignore_index=True)


print(f"Loaded {len(raw):,} rows")
# Out:
# Loaded 1,067,371 rows

# %% [markdown]
# # 2. Standardise Column Names

# %%
raw = raw.rename(columns={'Customer ID': 'CustomerID'})

con = duckdb.connect()
con.register('raw_retail', raw)

print("Columns:", list(raw.columns))
print(f"Rows: {len(raw):,}")
# Out:
# Columns: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'CustomerID', 'Country']
# Rows: 1,067,371

# %% [markdown]
# ## • Building CTE chain to clean raw data in stages, with each stage fixing one issue found in audit.
# ## • Some observations will have more than 1 of the data quality issues identified.
# ## • Before each stage, the number of data quality issues remaining will be counted to check if they have been removed in the previous stage

# %% [markdown]
# # 3. Remove Exact Duplicates

# %%
# Audit found 34,335 exact duplicate rows where all columns including the InvoiceDate timestamp are identical
# Likely data extraction issue as same transaction can't have happened twice.

con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    )
    SELECT COUNT(*) AS no_duplication_total FROM deduped;
""").fetchdf()
# Out:
#    no_duplication_total
# 0               1033036

# %% [markdown]
# # 4. Flag Cancellations

# %% [markdown]
# #### Audit found 19,494 cancellations with C-prefix in invoice and 22,950 with negative quantities.

# %%
# Remaining data quality issues
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * FROM raw_retail
    )
    SELECT
        COUNT(*) total_rows,
        SUM(CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' OR Quantity < 0 THEN 1 ELSE 0 END) AS cancellations,
        SUM(CASE WHEN Price <= 0 THEN 1 ELSE 0 END) AS invalid_price,
        SUM(CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END) AS null_customer_id,
        SUM(CASE WHEN Description IS NULL THEN 1 ELSE 0 END) AS null_description
    FROM deduped;
""").fetchdf()
# Out:
#    total_rows  cancellations  invalid_price  null_customer_id  \
# 0     1033036        22497.0         6019.0          235151.0
#
#    null_description
# 0            4275.0

# %%
# Flag Cancellations
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    )
    SELECT COUNT(*) AS rows_after_tag FROM cancellation_tag;
""").fetchdf()
# Out:
#    rows_after_tag
# 0         1033036

# %%
# Remaining data quality issues
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    )
    SELECT
        COUNT(*) total_rows,
        SUM(CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' OR Quantity < 0 THEN 1 ELSE 0 END) AS flagged_cancellations,
        SUM(CASE WHEN Price <= 0 THEN 1 ELSE 0 END) AS invalid_price,
        SUM(CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END) AS null_customer_id,
        SUM(CASE WHEN Description IS NULL THEN 1 ELSE 0 END) AS null_description
    FROM cancellation_tag;
""").fetchdf()
# Out:
#    total_rows  flagged_cancellations  invalid_price  null_customer_id  \
# 0     1033036                22497.0         6019.0          235151.0
#
#    null_description
# 0            4275.0

# %% [markdown]
# # 5. Remove zero/negative prices

# %% [markdown]
# #### Audit found 6,207 with zero/negative prices

# %%
# remove zero/negativ prices

con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    )
    SELECT COUNT(*) AS rows_after_filter FROM base_transactions;
""").fetchdf()
# Out:
#    rows_after_filter
# 0            1027017

# %%
# Remaining data quality issues
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    )
    SELECT
        COUNT(*) total_rows,
        SUM(CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' OR Quantity < 0 THEN 1 ELSE 0 END) AS flagged_cancellations,
        SUM(CASE WHEN Price <= 0 THEN 1 ELSE 0 END) AS invalid_price,
        SUM(CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END) AS null_customer_id,
        SUM(CASE WHEN Description IS NULL THEN 1 ELSE 0 END) AS null_description
    FROM base_transactions;
""").fetchdf()
# Out:
#    total_rows  flagged_cancellations  invalid_price  null_customer_id  \
# 0     1027017                19104.0            0.0          229202.0
#
#    null_description
# 0               0.0

# %% [markdown]
# ### Removing negative/zero prices also removed rows with null descriptions

# %% [markdown]
# # 6. Stock Code Cleaning

# %% [markdown]
# #### • Stock Code usually 5 or 6 characters long, composed of numbers and letters
# #### • Will remove stock codes with less than 5 characters and also look closer at stock codes with no numbers

# %%
# Stock Code Distribution
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    )
    SELECT
        LENGTH(CAST(StockCode AS VARCHAR)) AS code_length,
        COUNT(*) AS rows,
        COUNT(DISTINCT StockCode) AS distinct_codes,
        ANY_VALUE(StockCode) AS example
    FROM 
        base_transactions
    GROUP BY 
        code_length
    ORDER BY 
        rows DESC
""").fetchdf()
# Out:
#    code_length    rows  distinct_codes       example
# 0            5  897765            3401         20728
# 1            6  122113            1488        85099B
# 2            4    2113               3          POST
# 3            1    1660               5             M
# 4            3    1418               1           DOT
# 5            7    1336               8       15056BL
# 6            2     274               1            C2
# 7           12     178               8  BANK CHARGES
# 8            8      99              14      DCGS0072
# 9            9      61               3     DCGSSGIRL

# %%
# Stock Codes without numbers
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    )
    SELECT
        CAST(StockCode AS VARCHAR) AS code,
        ANY_VALUE(Description) AS description,
        COUNT(*) AS rows,
        ROUND(MIN(Price), 2) AS min_price,
        ROUND(MAX(Price), 2) AS max_price
    FROM 
        base_transactions
    WHERE 
        NOT REGEXP_MATCHES(CAST(StockCode AS VARCHAR), '[0-9]')
    GROUP BY 
        code
    """).fetchdf()
# Out:
#             code                          description  rows  min_price  \
# 0              B                      Adjust bad debt     1   11062.06
# 1              S                              SAMPLES   101       2.80
# 2       DCGSSBOY                       BOYS PARTY BAG    21       1.25
# 3           PADS           PADS TO MATCH ALL CUSHIONS    18       0.00
# 4      DCGSSGIRL                      GIRLS PARTY BAG    23       1.25
# 5              D                             Discount   173       0.01
# 6           POST                              POSTAGE  2079       0.50
# 7   BANK CHARGES                         Bank Charges   100       0.00
# 8      AMAZONFEE                           AMAZON FEE    36       1.00
# 9            DOT                       DOTCOM POSTAGE  1418       0.35
# 10        ADJUST  Adjustment by john on 26/01/2010 17    67       4.57
# 11             M                               Manual  1380       0.03
# 12             m                               Manual     5       2.55
# 13          CRUK                      CRUK Commission    16       1.60
#
#     max_price
# 0    11062.06
# 1      605.18
# 2        3.36
# 3       36.60
# 4        3.36
# 5     1867.86
# 6     8142.75
# 7    18910.69
# 8    17836.46
# 9     4505.17
# 10    5117.03
# 11   38970.00
# 12       4.00
# 13    1100.44

# %%
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    ),
    stock_code_length_without_numbers AS (
    SELECT *
       FROM 
           (SELECT *
               FROM base_transactions
               WHERE
                   LENGTH(StockCode) >=5
            )
    WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
    )
    SELECT
        LENGTH(CAST(StockCode AS VARCHAR)) AS code_length,
        COUNT(*) AS rows,
        COUNT(DISTINCT StockCode) AS distinct_codes,
        ANY_VALUE(StockCode) AS example
    FROM 
        stock_code_length_without_numbers
    GROUP BY 
        code_length
    ORDER BY 
        rows DESC
    """).fetchdf()
# Out:
#    code_length    rows  distinct_codes       example
# 0            5  897765            3401         22569
# 1            6  122046            1487        85123A
# 2            7    1336               8       15056BL
# 3            8      99              14      DCGS0004
# 4           12      78               7  gift_0001_20
# 5            9      25               2     DCGSSGIRL

# %%
con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    ),
    stock_code_length_without_numbers AS (
    SELECT *
       FROM 
           (SELECT *
               FROM base_transactions
               WHERE
                   LENGTH(StockCode) >=5
            )
    WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
    )
    SELECT
        *
    FROM 
        stock_code_length_without_numbers
    WHERE
        StockCode LIKE '%gift%'
    """).fetchdf()
# Out:
#    Invoice     StockCode                         Description  Quantity  \
# 0   558066  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00         1
# 1   491969  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00         1
# 2   495343  gift_0001_30  Dotcomgiftshop Gift Voucher £30.00         1
# 3   496247  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 4   561513  gift_0001_40  Dotcomgiftshop Gift Voucher £40.00         1
# ..     ...           ...                                 ...       ...
# 73  491971  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         2
# 74  510410  gift_0001_30  Dotcomgiftshop Gift Voucher £30.00         1
# 75  510637  gift_0001_10  Dotcomgiftshop Gift Voucher £10.00         1
# 76  512168  gift_0001_70  Dotcomgiftshop Gift Voucher £70.00         1
# 77  518662  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
#
#            InvoiceDate  Price  CustomerID         Country  is_cancellation
# 0  2011-06-24 15:45:00  41.67         NaN  United Kingdom                0
# 1  2009-12-14 17:57:00  69.56         NaN  United Kingdom                0
# 2  2010-01-22 18:05:00  25.53         NaN  United Kingdom                0
# 3  2010-01-29 16:11:00  17.02         NaN  United Kingdom                0
# 4  2011-07-27 15:12:00  33.33         NaN  United Kingdom                0
# ..                 ...    ...         ...             ...              ...
# 73 2009-12-14 18:37:00  17.39         NaN  United Kingdom                0
# 74 2010-05-28 17:25:00  25.53         NaN  United Kingdom                0
# 75 2010-06-02 11:54:00   8.51         NaN  United Kingdom                0
# 76 2010-06-14 11:24:00  59.57         NaN  United Kingdom                0
# 77 2010-08-10 14:08:00  17.02         NaN  United Kingdom                0
#
# [78 rows x 9 columns]

# %%
stock_code_clean = con.execute("""
    WITH deduped AS (
        SELECT DISTINCT * 
        FROM raw_retail
    ),
    cancellation_tag AS (
        SELECT *,
            CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                 OR Quantity < 0 
                 THEN 1 ELSE 0 END AS is_cancellation
        FROM deduped
    ),
    base_transactions AS (
        SELECT * 
        FROM cancellation_tag
        WHERE Price > 0
    ),
    stock_code_length_without_numbers AS (
    SELECT *
       FROM 
           (SELECT *
               FROM base_transactions
               WHERE
                   LENGTH(StockCode) >=5
            )
    WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
    )
    SELECT
        *
    FROM 
        stock_code_length_without_numbers
    WHERE
        StockCode NOT LIKE '%gift%'
    """).fetchdf()

# %%
con.execute("""
    SELECT 
        *
    FROM
        stock_code_clean
    WHERE
        Description LIKE '%dot%'
    """).fetchdf()
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, CustomerID, Country, is_cancellation]
# Index: []

# %% [markdown]
# ### Audit found 1,232 stock codes with more than one description

# %%
# How many stock codes still have multiple descriptions after cleaning so far
con.execute("""
    SELECT COUNT(*) AS affected_stock_codes
    FROM (
        SELECT StockCode
        FROM stock_code_clean
        GROUP BY StockCode
        HAVING COUNT(DISTINCT Description) > 1
    )
""").fetchdf()
# Out:
#    affected_stock_codes
# 0                   646

# %%
# Of those how many are formatting noise (case/whitespace) vs relabelling
con.execute("""
    WITH normalised AS (
        SELECT
            StockCode,
            Description,
            UPPER(TRIM(Description)) AS description_clean
        FROM stock_code_clean
    )
    SELECT
        StockCode,
        COUNT(DISTINCT Description) AS raw_variants,
        COUNT(DISTINCT description_clean) AS clean_variants
    FROM normalised
    GROUP BY StockCode
    HAVING COUNT(DISTINCT Description) > 1

""").fetchdf()
# Out:
#     StockCode  raw_variants  clean_variants
# 0       21391             2               2
# 1       22349             2               2
# 2       37471             2               2
# 3       22090             2               2
# 4       72817             2               2
# ..        ...           ...             ...
# 641     23283             2               2
# 642     23252             2               2
# 643     22360             2               2
# 644     22202             2               2
# 645     21238             2               2
#
# [646 rows x 3 columns]

# %%
con.execute("""
    SELECT
        StockCode,
        Description,
        Count(*)
    FROM
        stock_code_clean
    WHERE
        StockCode = '21391'
    GROUP BY
        StockCode,
        Description

""").fetchdf()
# Out:
#   StockCode                          Description  count_star()
# 0     21391  FRENCH EMROIDR LAVENDER SCENT HEART            68
# 1     21391          FRENCH LAVENDER SCENT HEART           111

# %%
con.execute("""
    SELECT
        StockCode,
        Description,
        Count(*)
    FROM
        stock_code_clean
    WHERE
        StockCode = '22349'
    GROUP BY
        StockCode,
        Description

""").fetchdf()
# Out:
#   StockCode                     Description  count_star()
# 0     22349    DOG BOWL CHASING BALL DESIGN           238
# 1     22349  DOG BOWL , CHASING BALL DESIGN           141

# %%
con.execute("""
    WITH normalised AS (
        SELECT
            StockCode,
            Description,
            UPPER(TRIM(Description)) AS description_clean
        FROM stock_code_clean
    ),
    variant_summary AS (
        SELECT
            StockCode,
            COUNT(DISTINCT Description) AS raw_variants,
            COUNT(DISTINCT description_clean) AS clean_variants
        FROM normalised
        GROUP BY StockCode
        HAVING COUNT(DISTINCT Description) > 1
    )
    SELECT
        SUM(CASE WHEN clean_variants = 1 THEN 1 ELSE 0 END) AS formatting_only,
        SUM(CASE WHEN clean_variants > 1 THEN 1 ELSE 0 END) AS genuine_relabel,
        COUNT(*) AS total_affected
    FROM variant_summary
""").fetchdf()
# Out:
#    formatting_only  genuine_relabel  total_affected
# 0             25.0            621.0             646

# %% [markdown]
# #### INSIGHT:
# -  646 stock codes still carry multiple descriptions after existing cleaning
#
# -  Of these, only 25 are formatting differences (case,whitespace). The other 621 are genuine relabelling e.g. "FRENCH EMROIDR LAVENDER SCENT HEART" vs "FRENCH     LAVENDER SCENT HEART" for the same product
#
# -  The problem is mostly text based rather than formatting based and TRIM/UPPER cannot resolve it. Description alone is not a reliable grouping key. Any product    analysis should group by StockCode and resolve to the most frequent description for that code

# %%
con.execute("""
    WITH ranked AS (
        SELECT
            StockCode,
            Description,
            COUNT(*) AS rows,
            ROW_NUMBER() OVER (PARTITION BY StockCode ORDER BY COUNT(*) DESC) AS rn,
            SUM(COUNT(*)) OVER (PARTITION BY StockCode) AS total_rows
        FROM stock_code_clean
        GROUP BY StockCode, Description
    )
    SELECT
        StockCode,
        Description AS minority_label,
        rows AS minority_rows,
        total_rows,
        ROUND(rows * 100.0 / total_rows, 1) AS minority_share_pct
    FROM ranked
    WHERE rn > 1
    ORDER BY StockCode DESC
    LIMIT 30
""").fetchdf()
# Out:
#    StockCode                       minority_label  minority_rows  total_rows  \
# 0      90208  PAIR OF ENAMEL FLOWER CLUSTER SLIDE             30        69.0
# 1     90014C      SILVER AND BLACK ORBIT NECKLACE              2        20.0
# 2     90014B           GOLD M.O.P. ORBIT NECKLACE              2        28.0
# 3     90014A         SILVER M.O.P. ORBIT NECKLACE              6        40.0
# 4     85232b      SET OF 3 BABUSHKA STACKING TINS              8        22.0
# 5     85232B      SET OF 3 BABUSHKA STACKING TINS            179       572.0
# 6     85232A         SET/3 POLKADOT STACKING TINS             47       154.0
# 7      85227          SET/6 3D KIT CARDS FOR KIDS             51       457.0
# 8     85185B           PINK HORSE SOCK PUPPET KIT             17       187.0
# 9     85184c  SET 4 VALENTINE DECOUPAGE HEART BOX              2         6.0
# 10    85184C  SET 4 VALENTINE DECOUPAGE HEART BOX             63       348.0
# 11     85144      JARDIN ETCHED GLASS BUTTER DISH             33        74.0
# 12    85131D   BEADED CRYSTAL HEART PINK\ON STICK             11       267.0
# 13    85123A   CREAM HANGING HEART T-LIGHT HOLDER              9      5645.0
# 14     85103               SILVER T-LIGHT SETTING             20        92.0
# 15    85099B          JUMBO BAG RED WHITE SPOTTY             549      4126.0
# 16    85099B             RED RETROSPOT JUMBO BAG             218      4126.0
# 17    85014b      RED/WHITE DOTS RUFFLED UMBRELLA              5        35.0
# 18    85014a     BLACK/BLUE DOTS RUFFLED UMBRELLA              9        28.0
# 19    85014B      RED/WHITE DOTS RUFFLED UMBRELLA            424       912.0
# 20    85014A     BLACK/BLUE DOTS RUFFLED UMBRELLA            305       688.0
# 21    84997d    PINK 3 PIECE POLKADOT CUTLERY SET             16        84.0
# 22    84997d   PINK 3 PIECE MINI DOTS CUTLERY SET              1        84.0
# 23    84997c   BLUE 3 PIECE MINI DOTS CUTLERY SET              2        79.0
# 24    84997c    BLUE 3 PIECE POLKADOT CUTLERY SET             17        79.0
# 25    84997b    RED 3 PIECE MINI DOTS CUTLERY SET              7        88.0
# 26    84997b    RED 3 PIECE RETROSPOT CUTLERY SET             23        88.0
# 27    84997a   GREEN 3 PIECE POLKADOT CUTLERY SET             10        81.0
# 28    84997a  GREEN 3 PIECE MINI DOTS CUTLERY SET             11        81.0
# 29    84997D    PINK 3 PIECE POLKADOT CUTLERY SET            289      1111.0
#
#     minority_share_pct
# 0                 43.5
# 1                 10.0
# 2                  7.1
# 3                 15.0
# 4                 36.4
# 5                 31.3
# 6                 30.5
# 7                 11.2
# 8                  9.1
# 9                 33.3
# 10                18.1
# 11                44.6
# 12                 4.1
# 13                 0.2
# 14                21.7
# 15                13.3
# 16                 5.3
# 17                14.3
# 18                32.1
# 19                46.5
# 20                44.3
# 21                19.0
# 22                 1.2
# 23                 2.5
# 24                21.5
# 25                 8.0
# 26                26.1
# 27                12.3
# 28                13.6
# 29                26.0

# %% [markdown]
# # 7. Tag Guests

# %% [markdown]
# #### • 228,488 observations (22.7% of total) remaining have no CustomerID, their revenue is valid but will be filtered out for the customer analysis
# #### • Null values in Description were found in audit but have been removed in stage 5

# %%
# Tag rows with no CustomerID as guest transactions
con.execute("""
    WITH guest_tag AS (
        SELECT *,
        CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
        FROM stock_code_cleaned
    )
    SELECT
        SUM(is_guest) AS guest_rows,
        SUM(1 - is_guest) AS registered_rows,
        COUNT(*) AS total_rows
    FROM guest_tag;
    """).fetchdf()
# Out:
#    guest_rows  registered_rows  total_rows
# 0    227167.0         794182.0     1021349

# %%
# Remaining data quality issues

con.execute("""
    WITH guest_tag AS (
        SELECT *,
        CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
        FROM stock_code_cleaned
    )
    SELECT
        COUNT(*) total_rows,
        SUM(CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' OR Quantity < 0 THEN 1 ELSE 0 END) AS flagged_cancellations,
        SUM(CASE WHEN Price <= 0 THEN 1 ELSE 0 END) AS invalid_price,
        SUM(CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END) AS null_customer_id,
        SUM(is_guest) AS guest_total,
        SUM(CASE WHEN Description IS NULL THEN 1 ELSE 0 END) AS null_description
    FROM guest_tag;
""").fetchdf()
# Out:
#    total_rows  flagged_cancellations  invalid_price  null_customer_id  \
# 0     1021349                17919.0            0.0          227167.0
#
#    guest_total  null_description
# 0     227167.0               0.0

# %% [markdown]
# # 8. Derive Revenue

# %%
con.execute("""
    WITH guest_tag AS (
        SELECT *,
        CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
        FROM stock_code_cleaned
    ),
    revenue_derive AS (
        SELECT 
            *,
            Quantity * Price AS Revenue
        FROM guest_tag
    )
    SELECT
        MIN(Revenue) AS min_revenue,
        MAX(Revenue) AS max_revenue,
        ROUND(AVG(Revenue), 2) AS avg_revenue,
        ROUND(SUM(Revenue), 2) AS total_revenue,
        MIN(Quantity) AS min_quantity,
        MAX(Quantity) AS max_quantity,
        ROUND(AVG(Quantity), 2) AS avg_quantity,
        ROUND(SUM(Quantity), 2) AS total_quantity,
        MIN(Price) AS min_price,
        MAX(Price) AS max_price,
        ROUND(AVG(Price), 2) AS avg_price,
        ROUND(SUM(Price), 2) AS total_price,
        COUNT(*) total_rows
    FROM revenue_derive;
    """).fetchdf()
# Out:
#    min_revenue  max_revenue  avg_revenue  total_revenue  min_quantity  \
# 0    -168469.6     168469.6        18.53    18930056.81        -80995
#
#    max_quantity  avg_quantity  total_quantity  min_price  max_price  \
# 0         80995          10.5      10720433.0       0.03    1157.15
#
#    avg_price  total_price  total_rows
# 0       3.36   3436057.14     1021349

# %% [markdown]
# # 9. Date Features

# %%
con.execute("""
    WITH guest_tag AS (
        SELECT *,
        CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
        FROM stock_code_cleaned
    ),
    revenue_derive AS (
        SELECT 
            *,
            Quantity * Price AS Revenue
        FROM guest_tag
    ),
    cleaned AS (
        SELECT *,
            YEAR(InvoiceDate) AS Year,
            MONTH(InvoiceDate) AS Month,
            DAYOFWEEK(InvoiceDate) AS DayOfWeek,
            HOUR(InvoiceDate) AS Hour,
            CASE WHEN DAYOFWEEK(InvoiceDate) IN (0, 6) THEN 1 ELSE 0 END AS IsWeekend,
            DATE_TRUNC('week',  InvoiceDate) AS WeekStart,
            DATE_TRUNC('month', InvoiceDate) AS MonthStart
        FROM revenue_derive
    )
    SELECT * FROM cleaned LIMIT 5;
    """).fetchdf()
# Out:
#   Invoice StockCode                     Description  Quantity  \
# 0  528612     47580           TEA TIME DES TEA COSY         6
# 1  528612     21429  RED GINGHAM ROSE JEWELLERY BOX         6
# 2  528612     22111    SCOTTIE DOG HOT WATER BOTTLE         3
# 3  528613     22867         HAND WARMER BIRD DESIGN         1
# 4  528613     22903      CALENDAR FAMILY FAVOURITES         1
#
#           InvoiceDate  Price  CustomerID         Country  is_cancellation  \
# 0 2010-10-22 15:57:00   2.55     14728.0  United Kingdom                0
# 1 2010-10-22 15:57:00   1.65     14728.0  United Kingdom                0
# 2 2010-10-22 15:57:00   4.95     14728.0  United Kingdom                0
# 3 2010-10-22 15:57:00   4.21         NaN  United Kingdom                0
# 4 2010-10-22 15:57:00   5.91         NaN  United Kingdom                0
#
#    is_guest  Revenue  Year  Month  DayOfWeek  Hour  IsWeekend  WeekStart  \
# 0         0    15.30  2010     10          5    15          0 2010-10-18
# 1         0     9.90  2010     10          5    15          0 2010-10-18
# 2         0    14.85  2010     10          5    15          0 2010-10-18
# 3         1     4.21  2010     10          5    15          0 2010-10-18
# 4         1     5.91  2010     10          5    15          0 2010-10-18
#
#   MonthStart
# 0 2010-10-01
# 1 2010-10-01
# 2 2010-10-01
# 3 2010-10-01
# 4 2010-10-01

# %% [markdown]
# # 8. Validate Final Dataset

# %%
# Counting number of observations per data cleaning step

con.execute("""
    WITH deduped AS (
            SELECT DISTINCT * 
            FROM raw_retail
        ),
        cancellation_tag AS (
            SELECT *,
                CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                     OR Quantity < 0 
                     THEN 1 ELSE 0 END AS is_cancellation
            FROM deduped
        ),
        base_transactions AS (
            SELECT * 
            FROM cancellation_tag
            WHERE Price > 0
        ),
        stock_code_cleaned AS (
            SELECT *
               FROM 
                   (SELECT *
                       FROM base_transactions
                       WHERE
                           LENGTH(StockCode) >=5
                    )
            WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
        ),
        guest_tag AS (
            SELECT *,
            CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
            FROM stock_code_cleaned
        ),
        revenue_derive AS (
            SELECT 
                *,
                Quantity * Price AS Revenue
            FROM guest_tag
        ),
        cleaned AS (
            SELECT *,
                YEAR(InvoiceDate) AS Year,
                MONTH(InvoiceDate) AS Month,
                DAYOFWEEK(InvoiceDate) AS DayOfWeek,
                HOUR(InvoiceDate) AS Hour,
                CASE WHEN DAYOFWEEK(InvoiceDate) IN (0, 6) THEN 1 ELSE 0 END AS IsWeekend,
                DATE_TRUNC('week',  InvoiceDate) AS WeekStart,
                DATE_TRUNC('month', InvoiceDate) AS MonthStart
            FROM revenue_derive
        )
    SELECT 'raw' AS stage, COUNT(*) AS num_of_rows FROM raw_retail
    UNION ALL SELECT 'deduped', COUNT(*) FROM deduped
    UNION ALL SELECT 'flagged_cancellations', COUNT(*) FROM cancellation_tag
    UNION ALL SELECT 'base_transactions', COUNT(*) FROM base_transactions
    UNION ALL SELECT 'stock_code_cleaned', COUNT(*) FROM stock_code_cleaned
    UNION ALL SELECT 'with_guest_tag', COUNT(*) FROM guest_tag
    UNION ALL SELECT 'with_revenue', COUNT(*) FROM revenue_derive
    UNION ALL SELECT 'cleaned', COUNT(*) FROM cleaned;
    """).fetchdf()
# Out:
#                    stage  num_of_rows
# 0                    raw      1067371
# 1                deduped      1033036
# 2  flagged_cancellations      1033036
# 3      base_transactions      1027017
# 4     stock_code_cleaned      1021349
# 5         with_guest_tag      1021349
# 6           with_revenue      1021349
# 7                cleaned      1021349

# %%
# Checking if any data quality issues still exist
con.execute("""
    WITH deduped AS (
            SELECT DISTINCT * 
            FROM raw_retail
        ),
        cancellation_tag AS (
            SELECT *,
                CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                     OR Quantity < 0 
                     THEN 1 ELSE 0 END AS is_cancellation
            FROM deduped
        ),
        base_transactions AS (
            SELECT * 
            FROM cancellation_tag
            WHERE Price > 0
        ),
        stock_code_cleaned AS (
            SELECT *
                FROM 
                    (SELECT *
                        FROM base_transactions
                        WHERE
                            LENGTH(StockCode) >= 5
                    )
            WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
        ),
        guest_tag AS (
            SELECT *,
            CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
            FROM stock_code_cleaned
        ),
        revenue_derive AS (
            SELECT 
                *,
                Quantity * Price AS Revenue
            FROM guest_tag
        ),
        cleaned AS (
            SELECT *,
                YEAR(InvoiceDate) AS Year,
                MONTH(InvoiceDate) AS Month,
                DAYOFWEEK(InvoiceDate) AS DayOfWeek,
                HOUR(InvoiceDate) AS Hour,
                CASE WHEN DAYOFWEEK(InvoiceDate) IN (0, 6) THEN 1 ELSE 0 END AS IsWeekend,
                DATE_TRUNC('week',  InvoiceDate) AS WeekStart,
                DATE_TRUNC('month', InvoiceDate) AS MonthStart
            FROM revenue_derive
        )
    SELECT
        SUM(CASE WHEN Price <= 0 THEN 1 ELSE 0 END) AS bad_price,
        SUM(CASE WHEN is_cancellation  NOT IN (0, 1) THEN 1 ELSE 0 END) AS bad_cancellation_flag,
        SUM(CASE WHEN LENGTH(StockCode) < 5 
                   OR StockCode IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE') THEN 1 ELSE 0 END) AS bad_stock_code,
        SUM(CASE WHEN IsWeekend NOT IN (0, 1) THEN 1 ELSE 0 END) AS bad_weekend_flag,
        SUM(CASE WHEN is_guest  NOT IN (0, 1) THEN 1 ELSE 0 END) AS bad_guest_flag
    FROM cleaned;
    """).fetchdf()
# Out:
#    bad_price  bad_cancellation_flag  bad_stock_code  bad_weekend_flag  \
# 0        0.0                    0.0             0.0               0.0
#
#    bad_guest_flag
# 0             0.0

# %% [markdown]
# # 9. Saving cleaned data

# %%
con.execute("""
    CREATE OR REPLACE VIEW cleaned AS
    WITH deduped AS (
            SELECT DISTINCT * 
            FROM raw_retail
        ),
        cancellation_tag AS (
            SELECT *,
                CASE WHEN CAST(Invoice AS VARCHAR) LIKE 'C%' 
                     OR Quantity < 0 
                     THEN 1 ELSE 0 END AS is_cancellation
            FROM deduped
        ),
        base_transactions AS (
            SELECT * 
            FROM cancellation_tag
            WHERE Price > 0
        ),
        stock_code_cleaned AS (
            SELECT *
                FROM 
                    (SELECT *
                        FROM base_transactions
                        WHERE
                            LENGTH(StockCode) >= 5
                    )
            WHERE StockCode NOT IN ('BANK CHARGES', 'ADJUST', 'AMAZONFEE')
        ),
        guest_tag AS (
            SELECT *,
            CASE WHEN CustomerID IS NULL THEN 1 ELSE 0 END AS is_guest
            FROM stock_code_cleaned
        ),
        revenue_derive AS (
            SELECT 
                *,
                Quantity * Price AS Revenue
            FROM guest_tag
        )
    SELECT *,
        YEAR(InvoiceDate) AS Year,
        MONTH(InvoiceDate) AS Month,
        DAYOFWEEK(InvoiceDate) AS DayOfWeek,
        HOUR(InvoiceDate) AS Hour,
        CASE WHEN DAYOFWEEK(InvoiceDate) IN (0, 6) THEN 1 ELSE 0 END AS IsWeekend,
        DATE_TRUNC('week',  InvoiceDate) AS WeekStart,
        DATE_TRUNC('month', InvoiceDate) AS MonthStart
    FROM revenue_derive;
""")

# %%
# All valid sales data including guests
con.execute("""
    COPY (SELECT * FROM cleaned)
    TO '../data/processed/cleaned.csv' (HEADER, DELIMITER ',')
""")

# %%
# Registered customers only
con.execute("""
    COPY (SELECT * FROM cleaned WHERE is_guest = 0)
    TO '../data/processed/registered_only.csv' (HEADER, DELIMITER ',');
""")

# %% [markdown]
# # 10. Cleaning Summary

# %%
stats = con.execute("""
    SELECT
        COUNT(*) AS final_rows,
        COUNT(DISTINCT CustomerID) AS unique_customers,
        COUNT(DISTINCT StockCode) AS unique_products,
        COUNT(DISTINCT Country) AS unique_countries,
        ROUND(SUM(Revenue), 2) AS total_revenue
    FROM cleaned
""").fetchdf()

raw_rows    = len(raw)
final_rows  = stats['final_rows'][0]
removed     = raw_rows - final_rows
pct_removed = removed / raw_rows * 100
customers   = stats['unique_customers'][0]
products    = stats['unique_products'][0]
countries   = stats['unique_countries'][0]
revenue     = stats['total_revenue'][0]

print('=' * 60)
print('CLEANING SUMMARY')
print('=' * 60)
print(f"""
ROWS:
  Original:  {raw_rows:,}
  Final:     {final_rows:,}
  Removed:   {removed:,} ({pct_removed:.1f}%)

WHAT WAS REMOVED AND WHY:
  • Exact row duplicated, likely a data extraction issue as same transaction can't have happened twice or more at the same time down to the second.
  • Cancellations represented with 'C' prefix or negative quantities were flagged
  • Zero price removed as these were bad debt entries and negative price removed due to no clear meaning to them

FINAL DATASET (cleaned.csv):
  - Rows: {final_rows:,}
  - Customers: {customers:,} (registered only, guests excluded from count)
  - Products: {products:,}
  - Countries: {countries:,}
  - Total Revenue: GBP {revenue:,.2f}

OUTPUT FILES:
  • cleaned.csv ---> all valid sales including guests
  • registered_only.csv ---> valid sales with CustomerID for cohort and RFM

Ready for analysis.ipynb
""")
# Out:
# ============================================================
# CLEANING SUMMARY
# ============================================================
#
# ROWS:
#   Original:  1,067,371
#   Final:     1,021,349
#   Removed:   46,022 (4.3%)
#
# WHAT WAS REMOVED AND WHY:
#   • Exact row duplicated, likely a data extraction issue as same transaction can't have happened twice or more at the same time down to the second.
#   • Cancellations represented with 'C' prefix or negative quantities were flagged
#   • Zero price removed as these were bad debt entries and negative price removed due to no clear meaning to them
#
# FINAL DATASET (cleaned.csv):
#   - Rows: 1,021,349
#   - Customers: 5,875 (registered only, guests excluded from count)
#   - Products: 4,919
#   - Countries: 43
#   - Total Revenue: GBP 18,930,056.81
#
# OUTPUT FILES:
#   • cleaned.csv ---> all valid sales including guests
#   • registered_only.csv ---> valid sales with CustomerID for cohort and RFM
#
# Ready for analysis.ipynb
